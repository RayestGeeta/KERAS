# %%
import requests
url = 'http://biostat.mc.vanderbilt.edu/wiki/pub/Main/DataSets/titanic3.xls'

# %%
res = requests.get(url,stream=True)
with open('Titianic.xls','wb') as f:
    for chunk in res.iter_content(chunk_size = 1024):
        if chunk:
            f.write(chunk)

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('Titianic.xls')

# %%
df
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson, Mr. Harry
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 7          1         0                             Andrews, Mr. Thomas Jr
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia, Mr. Ramon
# 10         1         0                             Astor, Col. John Jacob
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
cols = ['survived','name','pclass','sex','age','sibsp','parch','fare','embarked']

# %%
Adf = df[cols]

# %%
Adf
# Out:
#       survived                                               name  pclass  \
# 0            1                      Allen, Miss. Elisabeth Walton       1
# 1            1                     Allison, Master. Hudson Trevor       1
# 2            0                       Allison, Miss. Helen Loraine       1
# 3            0               Allison, Mr. Hudson Joshua Creighton       1
# 4            0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1
# 5            1                                Anderson, Mr. Harry       1
# 6            1                  Andrews, Miss. Kornelia Theodosia       1
# 7            0                             Andrews, Mr. Thomas Jr       1
# 8            1      Appleton, Mrs. Edward Dale (Charlotte Lamson)       1
# 9            0                            Artagaveytia, Mr. Ramon       1
# 10           0                             Astor, Col. John Jacob       1
# 11           1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)       1
# ...

# %%
df = Adf.drop(['name'],axis=1)

# %%
df[:2]
# Out:
#    survived  pclass     sex      age  sibsp  parch      fare embarked
# 0         1       1  female  29.0000      0      0  211.3375        S
# 1         1       1    male   0.9167      1      2  151.5500        S

# %%
Adf.isnull().sum()
# Out:
# survived      0
# name          0
# pclass        0
# sex           0
# age         263
# sibsp         0
# parch         0
# fare          1
# embarked      2
# dtype: int64

# %%
age_mean = df['age'].mean()

# %%
df['age'] = df['age'].fillna(age_mean)

# %%
fare_mean = df['fare'].mean()
df['fare'] = df['fare'].fillna(fare_mean)

# %%
df['sex'] = df['sex'].map({'female':0,'male':1}).astype(int)

# %%
x_onehot = pd.get_dummies(data=df,columns = ['embarked'])

# %%
x_onehot[:2]
# Out:
#    survived  pclass  sex      age  sibsp  parch      fare  embarked_C  \
# 0         1       1    0  29.0000      0      0  211.3375           0
# 1         1       1    1   0.9167      1      2  151.5500           0
#
#    embarked_Q  embarked_S
# 0           0           1
# 1           0           1

# %%
ndarray = x_onehot.values

# %%
ndarray.shape
# Out:
# (1309, 10)

# %%
ndarray[0]
# Out:
# array([  1.    ,   1.    ,   0.    ,  29.    ,   0.    ,   0.    ,
#        211.3375,   0.    ,   0.    ,   1.    ])

# %%
print(ndarray[:,0][:2])
# Out:
# [1. 1.]

# %%
print(ndarray[:,1:][0])
# Out:
# [  1.       0.      29.       0.       0.     211.3375   0.       0.
#    1.    ]

# %% [markdown]
# # Normalizing

# %%
from sklearn import preprocessing

# %%
minmax_scale = preprocessing.MinMaxScaler(feature_range=(0,1))

# %%
scaledFeatures = minmax_scale.fit_transform(Features)

# %%
scaledFeatures[0]
# Out:
# array([0.        , 0.        , 0.36116884, 0.        , 0.        ,
#        0.41250333, 0.        , 0.        , 1.        ])

# %%
msk = np.random.rand(len(Adf))<0.8
train = Adf[msk]
test = Adf[~msk]

# %%
def PreprocessData(raw_df):
    df = raw_df.drop(['name'],axis=1)
    age_mean = df['age'].mean()
    df['age'] = df['age'].fillna(age_mean)
    fare_mean = df['fare'].mean()
    df['fare'] = df['fare'].fillna(age_mean)
    df['sex'] = df['sex'].map({'female':0,'male':1}).astype(int)
    x_onehot = pd.get_dummies(data=df,columns=['embarked'])
    
    ndarray = x_onehot.values
    Features = ndarray[:,1:]
    label = ndarray[:,0]
    
    minmax_scale = preprocessing.MinMaxScaler(feature_range=(0,1))
    scaledFeatures = minmax_scale.fit_transform(Features)
    
    return scaledFeatures,label

# %%
train_features,train_label = PreprocessData(train)
test_features,test_label = PreprocessData(test)

# %%
train_features[0]
# Out:
# array([0.        , 1.        , 0.00989011, 0.125     , 0.22222222,
#        0.2958059 , 0.        , 0.        , 1.        ])

# %%
train_label[:2]
# Out:
# array([1., 0.])

# %%
from keras.models import Sequential
from keras.layers import Dense,Dropout

# %%
model = Sequential()

# %%
model.add(Dense(units=40,kernel_initializer='uniform',activation='relu',input_dim = 9))

# %%
model.add(Dropout(0.2))

# %%
model.add(Dense(units=30,kernel_initializer='uniform',activation='relu'))

# %%
model.add(Dense(units=1,kernel_initializer='uniform',activation='sigmoid'))

# %%
model.compile(loss = 'binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_4 (Dense)              (None, 40)                400
# _________________________________________________________________
# dense_5 (Dense)              (None, 30)                1230
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 31
# ...
# Total params: 1,661
# Trainable params: 1,661
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
train_history = model.fit(x=train_features,
                         y=train_label,
                         validation_split=0.1,
                         epochs = 30,
                         batch_size = 30,verbose=2)
# Out:
# Train on 941 samples, validate on 105 samples
# Epoch 1/30
#  - 0s - loss: 0.6909 - acc: 0.5749 - val_loss: 0.6794 - val_acc: 0.7714
# Epoch 2/30
#  - 0s - loss: 0.6756 - acc: 0.6281 - val_loss: 0.6337 - val_acc: 0.7810
# Epoch 3/30
#  - 0s - loss: 0.6305 - acc: 0.7046 - val_loss: 0.5585 - val_acc: 0.7905
# Epoch 4/30
#  - 0s - loss: 0.5607 - acc: 0.7651 - val_loss: 0.5011 - val_acc: 0.7619
# Epoch 5/30
#  - 0s - loss: 0.5143 - acc: 0.7609 - val_loss: 0.4702 - val_acc: 0.7810
# Epoch 6/30
#  - 0s - loss: 0.5017 - acc: 0.7588 - val_loss: 0.4877 - val_acc: 0.7619
# Epoch 7/30
#  - 0s - loss: 0.4944 - acc: 0.7662 - val_loss: 0.4576 - val_acc: 0.7905
# Epoch 8/30
#  - 0s - loss: 0.4911 - acc: 0.7673 - val_loss: 0.4491 - val_acc: 0.8286
# Epoch 9/30
#  - 0s - loss: 0.4856 - acc: 0.7779 - val_loss: 0.4537 - val_acc: 0.7905
# Epoch 10/30
#  - 0s - loss: 0.4833 - acc: 0.7747 - val_loss: 0.4420 - val_acc: 0.8476
# Epoch 11/30
# ...

# %%
def show_train_history(train_history,train,validation):
    plt.plot(train_history.history[train])
    plt.plot(train_history.history[validation])
    plt.title('Train History')
    plt.ylabel(train)
    plt.xlabel('Epoch')
    plt.legend(['train','validation'],loc='upper left')
    plt.show()

# %%
show_train_history(train_history,'acc','val_acc')

# %%
show_train_history(train_history,'loss','val_loss')

# %%
scores = model.evaluate(x=test_features,y = test_label)
# Out:
# 263/263 [==============================] - 0s 24us/step

# %%
scores
# Out:
# [0.40670600012228064, 0.809885931785569]

# %%
Jack = pd.Series([0,'Jack',3,'male',23,1,0,5.0000,'S'])
Rose = pd.Series([1,'Rose',1,'female',20,1,0,100.0000,'S'])

# %%
JR_df = pd.DataFrame([list(Jack),list(Rose)],columns=cols)

# %%
Adf = pd.concat([Adf,JR_df])

# %%
AFeatures,Alabel = PreprocessData(Adf)

# %%
Aprobability = model.predict(AFeatures)

# %%
Aprobability[:10]
# Out:
# array([[0.97706336],
#        [0.5353934 ],
#        [0.97305864],
#        [0.3632192 ],
#        [0.96816874],
#        [0.29352736],
#        [0.94274867],
#        [0.32938114],
#        [0.9350853 ],
#        [0.34302005]], dtype=float32)

# %%
pd = Adf
pd.insert(len(Adf.columns),'Probability',Aprobability)

# %%
pd[-2:]
# Out:
#    survived  name  pclass     sex   age  sibsp  parch   fare embarked  \
# 0         0  Jack       3    male  23.0      1      0    5.0        S
# 1         1  Rose       1  female  20.0      1      0  100.0        S
#
#    Probability
# 0     0.166455
# 1     0.968978

# %%
pd[(pd['Probability']>0.9) & (pd['survived']==0)]
# Out:
#      survived                                             name  pclass  \
# 2           0                     Allison, Miss. Helen Loraine       1
# 4           0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1
# 105         0                         Evans, Miss. Edith Corse       1
# 169         0                       Isham, Miss. Ann Elizabeth       1
# 286         0           Straus, Mrs. Isidor (Rosalie Ida Blun)       1
#
#         sex   age  sibsp  parch      fare embarked  Probability
# 2    female   2.0      1      2  151.5500        S     0.973059
# 4    female  25.0      1      2  151.5500        S     0.968169
# 105  female  36.0      0      0   31.6792        C     0.980986
# 169  female  50.0      0      0   28.7125        C     0.978331
# 286  female  63.0      1      0  221.7792        S     0.955634

# %%
pd[:5]
# Out:
#    survived                                             name  pclass     sex  \
# 0         1                    Allen, Miss. Elisabeth Walton       1  female
# 1         1                   Allison, Master. Hudson Trevor       1    male
# 2         0                     Allison, Miss. Helen Loraine       1  female
# 3         0             Allison, Mr. Hudson Joshua Creighton       1    male
# 4         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1  female
#
#        age  sibsp  parch      fare embarked  Probability
# 0  29.0000      0      0  211.3375        S     0.977063
# 1   0.9167      1      2  151.5500        S     0.535393
# 2   2.0000      1      2  151.5500        S     0.973059
# 3  30.0000      1      2  151.5500        S     0.363219
# 4  25.0000      1      2  151.5500        S     0.968169
